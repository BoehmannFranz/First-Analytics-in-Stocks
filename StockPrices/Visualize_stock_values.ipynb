# %%
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns 

sns.set(rc={'figure.figsize':(11,4)})

df = pd.read_csv("stock_values_record.csv", index_col='datetime')
# cleaning
df.drop(['Unnamed: 0'], axis='columns', inplace=True)
#df.rename(columns = {"datetime":"Date"}, inplace=True)
# here comese the generic loop

# only get Daimler values from csv
df_daimler = df[df['names'].str.contains('DAIMLER')]
df_daimler['price'].plot(linewidth=0.6)

# %%
# # only get Alibaba values from csv
df_daimler = df[df['names'].str.contains('ALIBABA')]
df_daimler['price'].plot(linewidth=0.6)
